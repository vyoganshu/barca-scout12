# %%
import pandas as pd

# %%
barca_players = pd.read_csv("players_data_light-2024_2025.csv")
barca_players
# Out:
#         Rk             Player   Nation    Pos        Squad  \
# 0        1         Max Aarons  eng ENG     DF  Bournemouth
# 1        2         Max Aarons  eng ENG  DF,MF     Valencia
# 2        3     Rodrigo Abajas   es ESP     DF     Valencia
# 3        4     James Abankwah   ie IRL  DF,MF      Udinese
# 4        5  Keyliane Abdallah   fr FRA     FW    Marseille
# ...    ...                ...      ...    ...          ...
# 2849  2850       Edhy Zuliani   it ITA     DF     Toulouse
# 2850  2851   Szymon Żurkowski   pl POL     MF       Empoli
# 2851  2852    Martin Ødegaard   no NOR     MF      Arsenal
# 2852  2853        Milan Đurić   ba BIH     FW        Monza
# 2853  2854        Milan Đurić   ba BIH     FW        Parma
#
#                     Comp   Age    Born  MP  Starts  ...  Att (GK)  Thr  \
# 0     eng Premier League  25.0  2000.0   3       1  ...       NaN  NaN
# 1             es La Liga  25.0  2000.0   4       1  ...       NaN  NaN
# ...

# %%
barca_players['Squad'] = barca_players['Squad'].str.replace('\xa0', ' ', regex=False).str.strip()
barca_players = barca_players[barca_players['Squad'].str.lower() == 'barcelona']
barca_players
# Out:
#         Rk                 Player  Nation    Pos      Squad        Comp   Age  \
# 144    145          Ronald Araújo  uy URU     DF  Barcelona  es La Liga  26.0
# 215    216        Alejandro Balde  es ESP     DF  Barcelona  es La Liga  21.0
# 314    315            Marc Bernal  es ESP     MF  Barcelona  es La Liga  18.0
# 496    497            Marc Casado  es ESP     MF  Barcelona  es La Liga  21.0
# 554    555    Andreas Christensen  dk DEN     DF  Barcelona  es La Liga  29.0
# 633    634            Pau Cubarsí  es ESP     DF  Barcelona  es La Liga  18.0
# 764    765        Sergi Dominguez  es ESP     DF  Barcelona  es La Liga  20.0
# 877    878              Ansu Fati  es ESP     FW  Barcelona  es La Liga  22.0
# 924    925            Héctor Fort  es ESP     DF  Barcelona  es La Liga  18.0
# 969    970            Eric García  es ESP  DF,MF  Barcelona  es La Liga  24.0
# 981    982                   Gavi  es ESP  MF,FW  Barcelona  es La Liga  20.0
# ...

# %%
barca_players = barca_players[["Player","Nation","Pos","Age","PrgC","PrgP","PrgR","G+A","xG+xAG","Min","Squad"]]
barca_players
# Out:
#                      Player  Nation    Pos   Age  PrgC  PrgP  PrgR  G+A  \
# 144           Ronald Araújo  uy URU     DF  26.0     6    49     3    2
# 215         Alejandro Balde  es ESP     DF  21.0   107    93   246    4
# 314             Marc Bernal  es ESP     MF  18.0     0     8     2    0
# 496             Marc Casado  es ESP     MF  21.0    12   107    24    4
# 554     Andreas Christensen  dk DEN     DF  29.0     1    15     1    0
# 633             Pau Cubarsí  es ESP     DF  18.0    26   191     6    3
# 764         Sergi Dominguez  es ESP     DF  20.0     0    13     1    0
# 877               Ansu Fati  es ESP     FW  22.0     7     6    32    0
# 924             Héctor Fort  es ESP     DF  18.0    14    26    33    0
# 969             Eric García  es ESP  DF,MF  24.0    18   109    22    5
# 981                    Gavi  es ESP  MF,FW  20.0    13    77    42    2
# 1274        Frenkie de Jong  nl NED     MF  28.0    36   120    24    4
# ...
